# %%
import cv2
import matplotlib.pyplot as plt

# Load image
image = cv2.imread(r"C:\Users\oliver.koehn\Documents\projects\masterThesisLODS\userTasks\data\doc\X51008164996.jpg")

# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

# Visualize grayscale and binary images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(binary, cmap='gray')
plt.title('Binary Image')
plt.axis('off')

plt.show()

# %%
gray
# Out:
# array([[189, 188, 188, ..., 191, 191, 190],
#        [186, 187, 188, ..., 186, 186, 187],
#        [194, 198, 201, ..., 181, 183, 186],
#        ...,
#        [205, 206, 209, ..., 240, 233, 226],
#        [215, 209, 204, ..., 240, 233, 226],
#        [223, 212, 202, ..., 240, 233, 226]], dtype=uint8)
